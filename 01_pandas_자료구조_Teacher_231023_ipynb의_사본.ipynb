# %% [markdown]
# <a href="https://colab.research.google.com/github/SeongBumKim/Dataanalysis/blob/master/01_pandas_%EC%9E%90%EB%A3%8C%EA%B5%AC%EC%A1%B0_Teacher_231023_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 패키지 설치

# %%
#  imbgirl@naver.com  // 윤소영  // tbcase (카톡)

# %%
# !pip install mySUNI

# %%
import os
os.path.sep
# Out:
# '/'

# %%
import numpy as np
from mySUNI import cds
from IPython.display import Image

# %%
Image('https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1280px-Pandas_logo.svg.png', width=500)

# %% [markdown]
# ## Pandas

# %% [markdown]
# ### 개요

# %% [markdown]
# **관계형** 또는 **레이블이 된** 데이터로 쉽고 직관적 으로 작업할 수 있도록 설계되었고, 빠르고, 유연한 데이터 구조를 제공하는 Python 패키지입니다.
#
# 또한, 어떤 언어로도 사용할 수 있는 가장 **강력하고 유연한 오픈 소스 데이터 분석 / 조작 도구**입니다.
#
# Pandas는 다음의 종류의 데이터에 **적합한 분석 패키지**입니다.
#
# - SQL 테이블 또는 Excel 스프레드 시트에서와 같은 열과 행으로 이루어진 테이블 형식 데이터
# - 정렬되고 정렬되지 않은 시계열 데이터
# - 다른 형태의 관찰 / 통계 데이터 세트

# %% [markdown]
# ### Pandas 공식 문서

# %% [markdown]
# 공식 문서는 다음 링크에서 확인할 수 있습니다.
# - [공식 도큐먼트](https://pandas.pydata.org/docs/reference/index.html)

# %% [markdown]
# ## alias(별칭)와 버전

# %%
import pandas

# %%
pandas.__version__
# Out:
# '1.2.3'

# %% [markdown]
# pandas는 `pd`의 alias를 사용합니다.

# %%
import pandas as pd
import numpy as np

# %%
pd
# Out:
# <module 'pandas' from '/Users/baem1n/Library/Python/3.8/lib/python/site-packages/pandas/__init__.py'>

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ## Series

# %% [markdown]
# [도큐먼트](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html?highlight=series#pandas.Series)

# %% [markdown]
# Pandas의 Series는 1차원 배열로서 다음의 특징을 가집니다.
#
# - 데이터를 담는 **차원 배열 구조**를 가집니다.
# - **인덱스(index)를 사용 가능**합니다.
# - **데이터 타입**을 가집니다. (dtype)

# %% [markdown]
# ### Series의 생성

# %% [markdown]
# #### **numpy array**로 생성한 경우

# %%
arr = np.arange(100, 105)
arr
# Out:
# array([100, 101, 102, 103, 104])

# %%
s = pd.Series(arr)
s.name = "A"
s
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# Name: A, dtype: int64

# %% [markdown]
# #### dtype을 지정한 경우

# %%
s = pd.Series(arr, dtype='int32')
s
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int32

# %% [markdown]
# #### **list**로 생성한 경우

# %%
s = pd.Series(['A', 'B', 'C', 'D', 'E'])
s
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# dtype: object

# %% [markdown]
# #### 다양한 타입(type)의 데이터를 섞은 경우

# %% [markdown]
# Series에 다양한 데이터 타입의 데이터로 생성시, **object** 타입으로 생성됩니다.

# %%
s = pd.Series([91, 2.5, '스포츠', 4, 5.16])
s
# Out:
# 0      91
# 1     2.5
# 2     스포츠
# 3       4
# 4    5.16
# dtype: object

# %%
type(s[2])
# Out:
# str

# %% [markdown]
# ### index

# %%
s = pd.Series(['부장', '차장', '대리', '사원', '인턴'])
s
# Out:
# 0    부장
# 1    차장
# 2    대리
# 3    사원
# 4    인턴
# dtype: object

# %% [markdown]
# 기본 `index`는 0부터 숫자형 index가 부여됩니다.

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# 기본 부여된 `index`로 값을 조회할 수 있습니다.
#
# (indexing / slicing 은 이후에 좀 더 자세히 다룹니다.)

# %%
s[0]
# Out:
# '부장'

# %% [markdown]
# `.index`를 출력하면 **RangeIndex**로 표기됨을 확인할 수 있는데, 기본 부여된 **index는 0~ 순차적으로 부여**되기 때문입니다.

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# 내가 원하는 `index`를 **지정**할 수 있습니다.

# %%
s = pd.Series(['마케팅', '경영', '개발', '기획', '인사'],
              index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    마케팅
# b     경영
# c     개발
# d     기획
# e     인사
# dtype: object

# %%
display(s.index.values, s.values)
# Out:
# array(['a', 'b', 'c', 'd', 'e'], dtype=object)
# array(['마케팅', '경영', '개발', '기획', '인사'], dtype=object)

# %% [markdown]
# 새롭게 부여된 index로 **접근 가능**합니다.

# %%
s['c']
# Out:
# '개발'

# %% [markdown]
# 하지만, 기본 부여된 **숫자형 index로도 접근 가능**합니다.

# %%
s[-1]
# Out:
# '인사'

# %% [markdown]
# Series.`index`로도 index를 지정할 수 있습니다. 단, 지정하는 `index`의 갯수가 데이터의 갯수와 맞아야 합니다.

# %%
s.index = list('abcde')

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# ### values

# %% [markdown]
# `values`는 Series 데이터 값(value)만 **numpy array** 형식으로 가져 옵니다.

# %%
s.values
# Out:
# array(['마케팅', '경영', '개발', '기획', '인사'], dtype=object)

# %% [markdown]
# ### ndim - 차원

# %% [markdown]
# Series는 1차원 자료구조이기 때문에 ndim 출력시 **1**이 출력됩니다.

# %%
s.ndim
# Out:
# 1

# %% [markdown]
# ### shape

# %% [markdown]
# shape은 데이터의 모양(shape)을 알아보기 위하여 사용하는데, Series의 shape은 **데이터의 갯수**를 나타냅니다.
#
# **튜플(tuple)** 형식으로 출력됩니다.

# %%
s.shape
# Out:
# (5,)

# %% [markdown]
# ### NaN (Not a Number)

# %% [markdown]
# Pandas에서 **NaN 값**은 비어있는 **결측치 데이터**를 의미합니다.
#
# 임의로 비어있는 값을 대입하고자 할 때는 **numpy의 nan (np.nan)**을 입력합니다.

# %%
s = pd.Series(['선화', '소영', np.nan, '소정', '우영'])
s
# Out:
# 0     선화
# 1     소영
# 2    NaN
# 3     소정
# 4     우영
# dtype: object

# %% [markdown]
# ### 연습문제

# %% [markdown]
# 다음과 같은 Series를 생성해 주세요
#
# - s1 변수에 Series를 생성합니다.
# - dtype은 'float32'가 출력 되도록 합니다.

# %%
# 코드를 입력해 주세요
s1 = pd.Series(range(50, 55), dtype='float32')
s1
# Out:
# 0    50.0
# 1    51.0
# 2    52.0
# 3    53.0
# 4    54.0
# dtype: float32

# %% [markdown]
# 다음과 같은 Series를 생성해 주세요
#
# - s2 변수에 Series를 생성합니다.

# %%
# 코드를 입력해 주세요
data = ['apple', np.nan, 'banana', 'kiwi', 'gubong']
s2 = pd.Series(data, index=list('가나다라마'))
s2
# Out:
# 가     apple
# 나       NaN
# 다    banana
# 라      kiwi
# 마    gubong
# dtype: object

# %%
type(s2['나'])
# Out:
# float

# %% [markdown]
# ### indexing

# %%
s = pd.Series(['손흥민', '김연아', '박세리', '박찬호', '김연경'],
              index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    손흥민
# b    김연아
# c    박세리
# d    박찬호
# e    김연경
# dtype: object

# %% [markdown]
# index는 기본 부여된 **숫자형 index**와 내가 **새롭게 지정한 index** **둘 다 조회 가능**합니다.

# %%
s[1]
# Out:
# '김연아'

# %%
s['b']
# Out:
# '김연아'

# %% [markdown]
# ### fancy indexing

# %% [markdown]
# **fancy indexing**은 index를 선택하여 list로 정의하고, 선택한 index list로 indexing 하는 방법입니다.

# %%
s[['a','c']]
# Out:
# a    손흥민
# c    박세리
# dtype: object

# %%
i = ['a', 'c']
s[i]
# Out:
# a    손흥민
# c    박세리
# dtype: object

# %% [markdown]
# ### boolean indexing

# %% [markdown]
# **boolean index**은 index list 에서 **True인 index 만 선택**합니다.
#
# 주의해야할 점은 반드시 boolean index list의 갯수와 Series의 갯수가 맞아야 합니다.

# %%
s[[True, True, False, False, True]]
# Out:
# a    손흥민
# b    김연아
# e    김연경
# dtype: object

# %%
i = [True, True, False, False, True]
s[i]
# Out:
# a    손흥민
# b    김연아
# e    김연경
# dtype: object

# %%
condition = s.str.startswith('박')
s[condition]
# Out:
# c    박세리
# d    박찬호
# dtype: object

# %% [markdown]
# 조건을 걸어서 **boolean index list를 먼저 만들어 준 뒤 대입**할 수 있습니다.

# %%
s = pd.Series([29, 99, np.nan, 11, 56], index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    29.0
# b    99.0
# c     NaN
# d    11.0
# e    56.0
# dtype: float64

# %%
s > 50
# Out:
# a    False
# b     True
# c    False
# d    False
# e     True
# dtype: bool

# %%
s[s > 50]
# Out:
# b    99.0
# e    56.0
# dtype: float64

# %%
s[1:3]  # s.iloc[1:3]    # 3을 포함하지 않음
# Out:
# b    99.0
# c     NaN
# dtype: float64

# %%
s['b':'c']  # s.loc['b':'c']   # 'c'를 포함함
# Out:
# b    99.0
# c     NaN
# dtype: float64

# %% [markdown]
# ### 결측치 (NaN) 값 처리

# %% [markdown]
# `isnull()`과 `isna()`은 **NaN** 값을 찾는 함수 입니다.
#
# `isnull()`과 `isna()`는 결과가 동일합니다.

# %%
s.isnull()
# Out:
# a    False
# b    False
# c     True
# d    False
# e    False
# dtype: bool

# %%
s.isna()
# Out:
# a    False
# b    False
# c     True
# d    False
# e    False
# dtype: bool

# %% [markdown]
# 이를 boolean indexing에 적용해볼 수 있습니다.

# %%
s[s.isnull()]
# Out:
# c   NaN
# dtype: float64

# %%
s[s.isna()]
# Out:
# c   NaN
# dtype: float64

# %% [markdown]
# `notnull()`은 NaN값이 아닌, 즉 비어있지 않은 데이터를 찾는 함수 입니다.

# %%
s.notnull()
# Out:
# a     True
# b     True
# c    False
# d     True
# e     True
# dtype: bool

# %%
s[s.notnull()]
# Out:
# a    29.0
# b    99.0
# d    11.0
# e    56.0
# dtype: float64

# %% [markdown]
# ### slicing

# %% [markdown]
# **(주의)** 숫자형 index로 접근할 때는 뒷 index가 포함되지 않습니다.

# %%
s[1:3]
# Out:
# b    99.0
# c     NaN
# dtype: float64

# %% [markdown]
# 새롭게 지정한 인덱스는 시작 index와 끝 index **모두 포함**합니다.

# %%
s['b':'c']
# Out:
# b    99.0
# c     NaN
# dtype: float64

# %% [markdown]
# ## DataFrame

# %% [markdown]
# [도큐먼트](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)

# %% [markdown]
# `pd.DataFrame`
#
# - 2차원 데이터 구조 (Excel 데이터 시트를 생각하시면 됩니다)
# - 행(row), 열(column)으로 구성되어 있습니다.
# - 각 열(column)은 각각의 데이터 타입 (dtype)을 가집니다.

# %% [markdown]
# ### 생성

# %% [markdown]
# **list 를 통한 생성**할 수 있습니다. DataFrame을 만들 때는 **2차원 list를 대입**합니다.

# %%
pd.DataFrame([[1, 2, 3],
              [4, 5, 6],
              [7, 8, 9]])
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# 아래 예제와 같이 **columns를 지정**하면, DataFrame의 각 열에 대한 컬럼명이 붙습니다.

# %%
pd.DataFrame([[1, 2, 3],
              [4, 5, 6],
              [7, 8, 9]], columns=['가', '나', '다'])
# Out:
#    가  나  다
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# **dictionary를 통한 생성**도 가능합니다.
#
# 편리한 점은 dictionary의 **key 값이 자동으로 column 명으로 지정**됩니다.

# %%
data = {
    'name': ['Kim', 'Lee', 'Park'],
    'age': [24, 27, 34],
    'children': [2, 1, 3]
}

# %%
pd.DataFrame(data)
# Out:
#    name  age  children
# 0   Kim   24         2
# 1   Lee   27         1
# 2  Park   34         3

# %% [markdown]
# ### 속성

# %% [markdown]
# DataFrame은 다음의 **속성**을 가집니다.
#
# - **index**: index (기본 값으로 RangeIndex)
# - **columns**: column 명
# - **values**: numpy array형식의 데이터 값
# - **dtypes**: column 별 데이터 타입
# - **T**: DataFrame을 전치(Transpose)

# %%
data = {
    'name': ['Kim', 'Lee', 'Park'],
    'age': [24, 27, 34],
    'children': [2, 1, 3]
}

df = pd.DataFrame(data)
df
# Out:
#    name  age  children
# 0   Kim   24         2
# 1   Lee   27         1
# 2  Park   34         3

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'children'], dtype='object')

# %%
df.values
# Out:
# array([['Kim', 24, 2],
#        ['Lee', 27, 1],
#        ['Park', 34, 3]], dtype=object)

# %%
df.dtypes
# Out:
# name        object
# age          int64
# children     int64
# dtype: object

# %%
df.T
# Out:
#             0    1     2
# name      Kim  Lee  Park
# age        24   27    34
# children    2    1     3

# %% [markdown]
# ### index 지정

# %%
df
# Out:
#    name  age  children
# 0   Kim   24         2
# 1   Lee   27         1
# 2  Park   34         3

# %%
df.index = list('abc')
df
# Out:
#    name  age  children
# a   Kim   24         2
# b   Lee   27         1
# c  Park   34         3

# %% [markdown]
# (참고) DataFrame의 indexing / slicing은 나중에 세부적으로 다루도록 하겠습니다.

# %% [markdown]
# ### column 다루기

# %% [markdown]
# DataFrame에 key 값으로 column의 이름을 지정하여 column을 선택할 수 있습니다.
#
# 1개의 column을 가져올 수 있으며, **1개의 column 선택시 Series**가 됩니다.

# %%
df['name']
# Out:
# a     Kim
# b     Lee
# c    Park
# Name: name, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# 2개 이상의 column 선택은 **fancy indexing으로 가능**합니다.

# %%
df[['name', 'children']]
# Out:
#    name  children
# a   Kim         2
# b   Lee         1
# c  Park         3

# %% [markdown]
# (참고) column에 대한 slicing도 가능 하지만 이 부분도 나중에 다루도록 하겠습니다.

# %% [markdown]
# **rename**으로 column명 변경 가능합니다.

# %% [markdown]
# DataFrame.rename(columns={'바꾸고자 하는 컬럼명': '바꿀 컬럼명'})

# %%
df2 = df.rename(columns={'name': '이름', 'age':'나이'})

# %%
df2
# Out:
#      이름  나이  children
# a   Kim  24         2
# b   Lee  27         1
# c  Park  34         3

# %%
df
# Out:
#    name  age  children
# a   Kim   24         2
# b   Lee   27         1
# c  Park   34         3

# %%
df.rename({'name': '이름'}, axis=1)
# Out:
#      이름  age  children
# a   Kim   24         2
# b   Lee   27         1
# c  Park   34         3

# %% [markdown]
# `inplace=True` 옵션으로 변경사항을 바로 적용할 수 있습니다.

# %%
df.rename(columns={'name': '이름'}, inplace=True)
df
# Out:
#      이름  age  children
# a   Kim   24         2
# b   Lee   27         1
# c  Park   34         3

# %% [markdown]
# ### 연습문제

# %% [markdown]
# 다음의 DataFrame을 생성하세요
#
# - 생성된 DataFrame은 df 변수에 할당합니다.

# %%
# 코드를 입력해 주세요
df = pd.DataFrame({'food':['KFC', 'MaDonald', 'SchoolFood'],
                   'price': [1000, 2000, 3000],
                   'rating': [4.5, 3.9, 4.2]})
df
# Out:
#          food  price  rating
# 0         KFC   1000     4.5
# 1    MaDonald   2000     3.9
# 2  SchoolFood   3000     4.2

# %% [markdown]
# food 컬럼과 rating 컬럼만 선택하여 출력하세요

# %%
# 코드를 입력해 주세요
df[['food', 'rating']]
# Out:
#          food  rating
# 0         KFC     4.5
# 1    MaDonald     3.9
# 2  SchoolFood     4.2

# %% [markdown]
# food 컬럼명을 place로 컬럼명을 변경해 주세요

# %%
# 코드를 입력해 주세요
# ()
# []
# {}
# :
df.rename({'food':'place'}, axis='columns')
# Out:
#         place  price  rating
# 0         KFC   1000     4.5
# 1    MaDonald   2000     3.9
# 2  SchoolFood   3000     4.2

# %%
df.rename(columns={'food':'place'})
# Out:
#         place  price  rating
# 0         KFC   1000     4.5
# 1    MaDonald   2000     3.9
# 2  SchoolFood   3000     4.2
