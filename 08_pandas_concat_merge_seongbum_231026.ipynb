# %% [markdown]
# <a href="https://colab.research.google.com/github/SeongBumKim/Dataanalysis/blob/master/08_pandas_concat_merge_seongbum_231026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 패키지 설치

# %%
# !pip install mySUNI
# Out:
# Collecting mySUNI
#   Downloading mySUNI-2.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mySUNI) (4.66.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from mySUNI) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mySUNI) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mySUNI) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from mySUNI) (0.12.2)
# Collecting jupyter (from mySUNI)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from mySUNI) (7.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mySUNI) (2.31.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->mySUNI) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->mySUNI) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->mySUNI) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->mySUNI) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->mySUNI) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->mySUNI) (3.0.9)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter->mySUNI) (6.5.5)
# Collecting qtconsole (from jupyter->mySUNI)
#   Downloading qtconsole-5.4.4-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter->mySUNI) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter->mySUNI) (6.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mySUNI) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mySUNI) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mySUNI) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mySUNI) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mySUNI) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mySUNI) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mySUNI) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mySUNI) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mySUNI) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mySUNI) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mySUNI) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mySUNI) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mySUNI) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mySUNI) (2023.7.22)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mySUNI) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mySUNI) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mySUNI) (3.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->mySUNI) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->mySUNI) (6.3.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->mySUNI) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->mySUNI)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->mySUNI) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->mySUNI) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->mySUNI) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->mySUNI) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->mySUNI) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->mySUNI) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->mySUNI) (4.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mySUNI) (1.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (3.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (5.4.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (5.9.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->mySUNI) (1.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->mySUNI) (1.2.1)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter->mySUNI)
#   Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->mySUNI) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook->jupyter->mySUNI) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter->mySUNI) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter->mySUNI) (0.2.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter->mySUNI) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter->mySUNI) (4.19.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->mySUNI) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->mySUNI) (0.2.8)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter->mySUNI) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter->mySUNI) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter->mySUNI) (0.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->mySUNI) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->mySUNI) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->mySUNI) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->mySUNI) (0.10.6)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->mySUNI) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->mySUNI) (1.6.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->mySUNI) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->mySUNI) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->mySUNI) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->mySUNI) (2.21)
# Installing collected packages: qtpy, jedi, qtconsole, jupyter, mySUNI
# Successfully installed jedi-0.19.1 jupyter-1.0.0 mySUNI-2.0.0 qtconsole-5.4.4 qtpy-2.4.1

# %% [markdown]
# ## 모듈 import

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from mySUNI import cds
from IPython.display import Image

# %% [markdown]
# ## 데이터셋 로드

# %%
cds.list_data()
# Out:
#             name                                   info  \
# 0         서울시자전거                     서울시 따릉이 자전거 대여량 정보
# 1        서울시대중교통               서울시 대중교통(지하철, 버스) 이용객 정보
# 2      서울시주민등록인구                          서울시 주민등록인구 정보
# 3           유가정보                        2019년 서울시 유가 정보
# 4   PandasFileIO            Pandas File I/O 연습 문제용 데이터셋
# 5      CCTV데이터분석          mySUNI WorkShop - CCTV 데이터 분석
# 6      국민연금데이터분석          mySUNI WorkShop - 국민연금 데이터 분석
# 7    민간아파트가격동향분석      mySUNI WorkShop - 민간 아파트 가격 동향 분석
# 8         실거래가분석    mySUNI WorkShop - 2020년 아파트 실거래가 분석
# 9         유가가격분석       mySUNI WorkShop - 2020년 유가 가격 분석
# 10     중고차판매정보분석         mySUNI WorkShop - 중고차 판매 정보 분석
# 11          신용정보               사용자의 신용카드 대금 연체를 기준의 신용도
# 12       전국신규분양가          주택도시보증공사 전국 신규 민간 아파트 분양가격 정보
# 13        에너지 효율           난방부하 및 냉방부하 요구사항(에너지 효율)을 평가
# 14         보스턴집값                       보스턴 지역 집값 데이터 세트
# 15        와인유형분류  와인 유형(red, white) 분류를 위한 와인 품질 데이터 세트
# 16       사용자이탈예측                              사용자 이탈 예측
# 17  dogscats.zip                     서울시 따릉이 자전거 대여량 정보
# 18           rps                          가위/바위/보 손 이미지
# 19          spam                          스팸 메일 분류 데이터셋
# 20      PandasWS                  Pandas WorkShop용 데이터셋
#
#                                              filename
# 0                                 [seoul_bicycle.csv]
# 1                         [seoul_transportation.xlsx]
# 2                              [seoul_population.csv]
# 3           [gas_first_2019.csv, gas_second_2019.csv]
# 4   [mySUNI.xlsx, mySUNI_1.csv, mySUNI_2.csv, mySU...
# 5   [01. CCTV_in_Seoul.csv, 01. population_in_Seou...
# 6                              [national_pension.csv]
# 7                             [seoul_house_price.csv]
# 8           [2020-seoul-apt-price.csv, loc_code.xlsx]
# 9           [gas_first_2019.csv, gas_second_2019.csv]
# 10                                     [vehicles.csv]
# 11                                  [credit-data.csv]
# 12                                  [house-price.csv]
# 13                                [ENB2012_data.xlsx]
# 14                                       [boston.csv]
# 15                     [red_wine.csv, white_wine.csv]
# 16    [class.csv, event.csv, logs.csv, user_info.csv]
# 17                                     [dogscats.zip]
# 18                                          [rps.zip]
# 19                                         [spam.csv]
# 20  [tips.csv, 따릉이_cat.csv, seoul_cctv.xlsx, test_...

# %%
cds.download_data('유가정보')
# Out:
# 파일 다운로드 완료
# ====================
#
# 데이터셋: 유가정보
# 파일경로: data/gas_first_2019.csv
#
# ====================
# 파일 다운로드 완료
# ====================
#
# 데이터셋: 유가정보
# 파일경로: data/gas_second_2019.csv
#
# ====================

# %% [markdown]
# **1월 부터 6월 까지 상반기** 데이터 로드

# %%
# 'data/gas_first_2019.csv' 를 읽어 gas1 이라는 이름을 부여합니다. (encoding='euc-kr')
def get_encoding(filename):
    import chardet

    with open(filename, "rb") as f:
        file_data = f.readline()

    result = chardet.detect(file_data)
    return result['encoding']


import os
filename = os.path.join('data', 'gas_first_2019.csv')
gas1 = pd.read_csv(filename, encoding=get_encoding(filename))

# %%
display(gas1.shape, gas1.tail())
# Out:
# (90590, 11)
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 90585  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190626  GS칼텍스   셀프
# 90586  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190627  GS칼텍스   셀프
# 90587  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190628  GS칼텍스   셀프
# 90588  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190629  GS칼텍스   셀프
# 90589  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190630  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# 90585      0  1529  1389     0
# 90586      0  1529  1389     0
# 90587      0  1529  1389     0
# 90588      0  1529  1389     0
# 90589      0  1529  1389     0

# %% [markdown]
# **7월 부터 12월 까지 하반기** 데이터 로드

# %%
# 'data/gas_second_2019.csv' 를 읽어 gas2 라는 이름을 부여합니다. (encoding='euc-kr')
import os
filename = os.path.join('data', 'gas_second_2019.csv')
gas2 = pd.read_csv(filename, encoding=get_encoding(filename))

# %%
display(gas2.shape, gas2.head())
# Out:
# (91124, 11)
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유
# 0   1777  1577  1477     0
# 1   1777  1577  1477     0
# 2   1777  1577  1477     0
# 3   1777  1577  1477     0
# 4   1777  1577  1477     0

# %% [markdown]
# ## concat() - 데이터 연결
#
# `concat()`은 DataFrame을 연결합니다.
#
# 단순하게 지정한 DataFrame을 이어서 연결합니다.

# %% [markdown]
# ### 행 방향으로 연결
#
# 기본 값인 `axis=0`이 지정되어 있고, 행 방향으로 연결합니다.

# %%
# gas1, gas2를 행 방향으로 연결합니다.
# index를 동일하게 가져오기 때문에 0,1,2,3...index 중복 발생 -> ignore index 사용
pd.concat([gas1, gas2], ignore_index=True)
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유
# 0        1673  1465  1365     0
# 1        1673  1465  1365     0
# 2        1673  1465  1365     0
# 3        1673  1465  1365     0
# 4        1673  1465  1365     0
# ...       ...   ...   ...   ...
# 181709      0  1540  1389  1100
# 181710      0  1540  1389  1100
# 181711      0  1540  1389  1100
# 181712      0  1540  1389  1100
# 181713      0  1540  1389  1100
#
# [181714 rows x 11 columns]

# %% [markdown]
# 연결시 위와 같이 index가 초기화가 되지 않아 **전체 DataFrame의 개수와 index가 맞지 않는** 모습입니다.

# %%
pd.concat([gas1, gas2]).iloc[90588:90593]
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 90588  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190629  GS칼텍스   셀프
# 90589  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190630  GS칼텍스   셀프
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# 90588      0  1529  1389     0
# 90589      0  1529  1389     0
# 0       1777  1577  1477     0
# 1       1777  1577  1477     0
# 2       1777  1577  1477     0

# %% [markdown]
# 연결 하면서 **index를 무시하고 연결** 할 수 있습니다.

# %%
# ignore_index=True 를 사용하여 gas1, gas2를 행방향 연결하면서
# index를 무시하고 새롭게 RangeIndex를 사용하도록 합니다.
gas = pd.concat([gas1, gas2], ignore_index=True)
gas
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유
# 0        1673  1465  1365     0
# 1        1673  1465  1365     0
# 2        1673  1465  1365     0
# 3        1673  1465  1365     0
# 4        1673  1465  1365     0
# ...       ...   ...   ...   ...
# 181709      0  1540  1389  1100
# 181710      0  1540  1389  1100
# 181711      0  1540  1389  1100
# 181712      0  1540  1389  1100
# 181713      0  1540  1389  1100
#
# [181714 rows x 11 columns]

# %% [markdown]
# ### 열 방향으로 연결
#
# 열(column) 방향으로 연결 가능하며, `axis=1`로 지정합니다.

# %%
# 실습을 위한 DataFrame 임의 분할
gas1 = gas.iloc[:, :5]
gas2 = gas.iloc[:, 5:]

# %%
gas1.head()
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유
# 0   1673  1465  1365     0
# 1   1673  1465  1365     0
# 2   1673  1465  1365     0
# 3   1673  1465  1365     0
# 4   1673  1465  1365     0

# %%
gas2.head()
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유
# 0   1777  1577  1477     0
# 1   1777  1577  1477     0
# 2   1777  1577  1477     0
# 3   1777  1577  1477     0
# 4   1777  1577  1477     0

# %%
# gas1, gas2 를 열방향으로 연결합니다.
pd.concat([gas1, gas2], axis=1)
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유
# 0        1673  1465  1365     0
# 1        1673  1465  1365     0
# 2        1673  1465  1365     0
# 3        1673  1465  1365     0
# 4        1673  1465  1365     0
# ...       ...   ...   ...   ...
# 181709      0  1540  1389  1100
# 181710      0  1540  1389  1100
# 181711      0  1540  1389  1100
# 181712      0  1540  1389  1100
# 181713      0  1540  1389  1100
#
# [181714 rows x 11 columns]

# %% [markdown]
# ## merge() - 병합
#
# 서로 **다른 구성의 DataFrame이지만, 공통된 key값(컬럼)을 가지고 있다면 병합**할 수 있습니다.

# %%
df1 = pd.DataFrame({
    '고객명': ['박세리', '이대호', '손흥민', '김연아', '마이클조던'],
    '생년월일': ['1980-01-02', '1982-02-22', '1993-06-12', '1988-10-16', '1970-03-03'],
    '성별': ['여자', '남자', '남자', '여자', '남자']})
df1
# Out:
#      고객명        생년월일  성별
# 0    박세리  1980-01-02  여자
# 1    이대호  1982-02-22  남자
# 2    손흥민  1993-06-12  남자
# 3    김연아  1988-10-16  여자
# 4  마이클조던  1970-03-03  남자

# %%
df2 = pd.DataFrame({
    '고객명': ['김연아', '박세리', '손흥민', '이대호', '타이거우즈'],
    '연봉': ['2000원', '3000원', '1500원', '2500원', '3500원']})
df2
# Out:
#      고객명     연봉
# 0    김연아  2000원
# 1    박세리  3000원
# 2    손흥민  1500원
# 3    이대호  2500원
# 4  타이거우즈  3500원

# %%
# df1, df2를 병합합니다.  (고객명 기준) - 같은 이름이므로 별도 지정 필요 없음
pd.merge(df1, df2)
# Out:
#    고객명        생년월일  성별     연봉
# 0  박세리  1980-01-02  여자  3000원
# 1  이대호  1982-02-22  남자  2500원
# 2  손흥민  1993-06-12  남자  1500원
# 3  김연아  1988-10-16  여자  2000원

# %% [markdown]
# ### 병합하는 방법 4가지

# %% [markdown]
# `how` 옵션 값을 지정하여 4가지 방식으로 병합을 할 수 있으며, 각기 다른 결과를 냅니다.

# %% [markdown]
# - **how** : {`left`, `right`, `outer`, `inner`},
# - **default**로 설정된 값은`inner` 입니다.

# %%
# how='inner' 입니다. 양쪽 다 값이 있으면 가져옴
pd.merge(df1, df2)
# Out:
#    고객명        생년월일  성별     연봉
# 0  박세리  1980-01-02  여자  3000원
# 1  이대호  1982-02-22  남자  2500원
# 2  손흥민  1993-06-12  남자  1500원
# 3  김연아  1988-10-16  여자  2000원

# %%
pd.merge(df1, df2, how='left')    # 왼쪽 값은 다 가져옴 오른쪽 값 없으면 NaN
# Out:
#      고객명        생년월일  성별     연봉
# 0    박세리  1980-01-02  여자  3000원
# 1    이대호  1982-02-22  남자  2500원
# 2    손흥민  1993-06-12  남자  1500원
# 3    김연아  1988-10-16  여자  2000원
# 4  마이클조던  1970-03-03  남자    NaN

# %%
pd.merge(df1, df2, how='right')    # 오른쪽 값은 다 가져옴 왼쪽 값 없으면 NaN
# Out:
#      고객명        생년월일   성별     연봉
# 0    김연아  1988-10-16   여자  2000원
# 1    박세리  1980-01-02   여자  3000원
# 2    손흥민  1993-06-12   남자  1500원
# 3    이대호  1982-02-22   남자  2500원
# 4  타이거우즈         NaN  NaN  3500원

# %%
pd.merge(df1, df2, how='outer')    # 양쪽 다 포함
# Out:
#      고객명        생년월일   성별     연봉
# 0    박세리  1980-01-02   여자  3000원
# 1    이대호  1982-02-22   남자  2500원
# 2    손흥민  1993-06-12   남자  1500원
# 3    김연아  1988-10-16   여자  2000원
# 4  마이클조던  1970-03-03   남자    NaN
# 5  타이거우즈         NaN  NaN  3500원

# %% [markdown]
# ### 병합하려는 컬럼의 이름이 다른 경우

# %%
df1 = pd.DataFrame({
    '이름': ['박세리', '이대호', '손흥민', '김연아', '마이클조던'],
    '생년월일': ['1980-01-02', '1982-02-22', '1993-06-12', '1988-10-16', '1970-03-03'],
    '성별': ['여자', '남자', '남자', '여자', '남자']})
df1
# Out:
#       이름        생년월일  성별
# 0    박세리  1980-01-02  여자
# 1    이대호  1982-02-22  남자
# 2    손흥민  1993-06-12  남자
# 3    김연아  1988-10-16  여자
# 4  마이클조던  1970-03-03  남자

# %%
df2 = pd.DataFrame({
    '고객명': ['김연아', '박세리', '손흥민', '이대호', '타이거우즈'],
    '연봉': ['2000원', '3000원', '1500원', '2500원', '3500원']})
df2
# Out:
#      고객명     연봉
# 0    김연아  2000원
# 1    박세리  3000원
# 2    손흥민  1500원
# 3    이대호  2500원
# 4  타이거우즈  3500원

# %% [markdown]
# `left_on`가 `right_on`을 지정합니다.
#
# 이름과 고객명 컬럼이 모두 drop되지 않고 살아 있음을 확인합니다.

# %%
pd.merge(df1, df2, left_on='이름', right_on='고객명')
# Out:
#     이름        생년월일  성별  고객명     연봉
# 0  박세리  1980-01-02  여자  박세리  3000원
# 1  이대호  1982-02-22  남자  이대호  2500원
# 2  손흥민  1993-06-12  남자  손흥민  1500원
# 3  김연아  1988-10-16  여자  김연아  2000원
